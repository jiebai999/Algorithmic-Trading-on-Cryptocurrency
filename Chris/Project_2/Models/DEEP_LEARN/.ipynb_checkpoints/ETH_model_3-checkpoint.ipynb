# %%
# Initial imports
import numpy as np
import pandas as pd
from pathlib import Path

# %matplotlib inline

# %%
 # Set path to CSV and read in CSV
csv_path = Path("DATA/ETH/ETH_DATA.csv")
eth_df=pd.read_csv(csv_path)

# %%
 # Set index as Date
eth_df = eth_df.set_index(pd.to_datetime(eth_df["Date"], infer_datetime_format=True))

# Display sample data
eth_df.head(10)
# Out:
#            Currency        Date  Closing Price (USD)  24h Open (USD)  \
# Date
# 2015-08-09      ETH  2015-08-09             0.909046        1.749289
# 2015-08-10      ETH  2015-08-10             0.692321        0.909046
# 2015-08-11      ETH  2015-08-11             0.668067        0.692321
# 2015-08-12      ETH  2015-08-12             0.850151        0.668067
# 2015-08-13      ETH  2015-08-13             1.266023        0.850151
# 2015-08-14      ETH  2015-08-14             1.951460        1.266023
# 2015-08-15      ETH  2015-08-15             1.591219        1.951460
# 2015-08-16      ETH  2015-08-16             1.693707        1.591219
# 2015-08-17      ETH  2015-08-17             1.423244        1.693707
# 2015-08-18      ETH  2015-08-18             1.199595        1.423244
#
#             24h High (USD)  24h Low (USD)
# Date
# 2015-08-09        1.916540       0.794497
# 2015-08-10        0.909046       0.692321
# 2015-08-11        0.692321       0.654331
# 2015-08-12        1.148621       0.668067
# 2015-08-13        1.266023       0.850151
# 2015-08-14        2.073329       1.149458
# 2015-08-15        2.225695       1.591219
# 2015-08-16        1.768860       1.591219
# 2015-08-17        1.693707       1.099489
# 2015-08-18        1.469168       1.193790

# %%
#check for na
eth_df.isnull().values.any()
# Out:
# False

# %%
#check main_df to see if everything is correct 
eth_df.head()
# Out:
#            Currency        Date  Closing Price (USD)  24h Open (USD)  \
# Date
# 2015-08-09      ETH  2015-08-09             0.909046        1.749289
# 2015-08-10      ETH  2015-08-10             0.692321        0.909046
# 2015-08-11      ETH  2015-08-11             0.668067        0.692321
# 2015-08-12      ETH  2015-08-12             0.850151        0.668067
# 2015-08-13      ETH  2015-08-13             1.266023        0.850151
#
#             24h High (USD)  24h Low (USD)
# Date
# 2015-08-09        1.916540       0.794497
# 2015-08-10        0.909046       0.692321
# 2015-08-11        0.692321       0.654331
# 2015-08-12        1.148621       0.668067
# 2015-08-13        1.266023       0.850151

# %%
 # Importing required Keras modules
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# %%
#assign atributes to names
#future period desides how many days ahead data will be 
FUTURE_PERIOD_PREDICT = 3

# %%
#set data 3 days back to compensate for lag
def add_future_column(eth_df):
    main_df= eth_df.copy()
    main_df['future'] = eth_df["Closing Price (USD)"].shift(-FUTURE_PERIOD_PREDICT)
    
    main_df.dropna(inplace=True)

    main_df.head()
    
    return main_df

# %%
#run df thorugh the function to add future coulumn to eth_eval
main_df = add_future_column(eth_df)
main_df.head()
# Out:
#            Currency        Date  Closing Price (USD)  24h Open (USD)  \
# Date
# 2015-08-09      ETH  2015-08-09             0.909046        1.749289
# 2015-08-10      ETH  2015-08-10             0.692321        0.909046
# 2015-08-11      ETH  2015-08-11             0.668067        0.692321
# 2015-08-12      ETH  2015-08-12             0.850151        0.668067
# 2015-08-13      ETH  2015-08-13             1.266023        0.850151
#
#             24h High (USD)  24h Low (USD)    future
# Date
# 2015-08-09        1.916540       0.794497  0.850151
# 2015-08-10        0.909046       0.692321  1.266023
# 2015-08-11        0.692321       0.654331  1.951460
# 2015-08-12        1.148621       0.668067  1.591219
# 2015-08-13        1.266023       0.850151  1.693707

# %%
def get_data():
    
     # Set path to CSV and read in CSV
    csv_path = Path("DATA/ETH/ETH_DATA.csv")
    eth_df=pd.read_csv(csv_path)
    
     # Set index as Date
    eth_df = eth_df.set_index(pd.to_datetime(eth_df["Date"], infer_datetime_format=True))
    
    #run df thorugh the function to add future coulumn to eth_eval
    main_df = add_future_column(eth_df)
    # save data coulmnn 
    date = main_df.Date
    
    
    #remove eth column 
    main_df = main_df.drop(columns = ['Currency'])
    main_df = main_df.drop(columns= ['Date'])

    columns = main_df.columns
    
    
    # Importing the MinMaxScaler from sklearn
    from sklearn.preprocessing import MinMaxScaler

    # Create a MinMaxScaler object
    scaler = MinMaxScaler()

    scaler.fit(main_df)
    
    main_array = scaler.transform(main_df)
    
    RES = pd.DataFrame(data=main_array, columns = columns)
    
    RES = RES.set_index(date)
    
    
    
    return RES,scaler

# %%
#reshape
def expand_windowed_data(X1,length_of_sample):
    """LSTM is expecting a 3-D data structure with (batch number, time steps, features)"""
    X2 = create_rolling_windows(X1, length_of_sample)
    X3 = X2.reshape(-1, length_of_sample, X1.shape[1])
    return X3

# %%
def create_rolling_windows(values, count):
    """create a set of records that have the first count rows, then the same number of rows offset by one etc.
    example=abcdefghijklmn
    create_rolling_window(example, 3)
    would return abcbcdcdedefefgfghghihijijkjklklmlmn"""
    firstitem = values[:count]
    items = [values[window_start:window_start + count] for window_start in range(1, 1 + len(values) - count)]
    total = np.append(firstitem, items)
    return total

# %%
main_df, scaler = get_data()

# %%
main_df
# Out:
#             Closing Price (USD)  24h Open (USD)  24h High (USD)  \
# Date
# 2015-08-09             0.000116        0.000316        0.000325
# 2015-08-10             0.000064        0.000115        0.000096
# 2015-08-11             0.000058        0.000063        0.000046
# 2015-08-12             0.000102        0.000057        0.000150
# 2015-08-13             0.000203        0.000101        0.000177
# ...                         ...             ...             ...
# 2021-07-19             0.442534        0.452552        0.437966
# 2021-07-20             0.429891        0.435115        0.420265
# 2021-07-21             0.476256        0.427497        0.463770
# 2021-07-22             0.485271        0.477577        0.467042
# 2021-07-23             0.503232        0.484508        0.477946
#
#             24h Low (USD)    future
# Date
# 2015-08-09       0.000096  0.000102
# 2015-08-10       0.000070  0.000203
# 2015-08-11       0.000060  0.000369
# 2015-08-12       0.000064  0.000281
# 2015-08-13       0.000110  0.000306
# ...                   ...       ...
# 2021-07-19       0.458085  0.485271
# 2021-07-20       0.436956  0.503232
# 2021-07-21       0.445578  0.524497
# 2021-07-22       0.495249  0.522859
# 2021-07-23       0.506904  0.538513
#
# [2176 rows x 5 columns]

# %%
X1= main_df[["Closing Price (USD)"]].to_numpy()
y1 = main_df[["future"]].to_numpy()

# %%
#split data
split = int(0.7 * len(X1))
X_train = X1[: split]
X_test = X1[split:]

y_train = y1[: split]
y_test = y1[split:]

# %%
X_train = expand_windowed_data(X_train,9)
y_train = expand_windowed_data(y_train,9)

X_test = expand_windowed_data(X_test,9)
y_test = expand_windowed_data(y_test,9)

# %%
print(X1.shape,y1.shape)
print(X_train.shape,y_train.shape)
# Out:
# (2176, 1) (2176, 1)
# (1515, 9, 1) (1515, 9, 1)

# %%
def create_model(shape):
    model = Sequential()
    model.add(LSTM(16, input_shape=shape, return_sequences=True))
    model.add(LSTM(16, return_sequences=True))
    model.add(Dense(2))
    return model

# %%
model = create_model(X_train.shape[1:3]) #The last two entries in the shape, data has shape (batches, timesteps, features)
model.compile(optimizer = "adam", loss="mse")
model.fit(X_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 48/48 [==============================] - 5s 7ms/step - loss: 0.0033
# Epoch 2/100
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0014
# Epoch 3/100
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0011
# Epoch 4/100
# 48/48 [==============================] - 0s 6ms/step - loss: 8.6852e-04
# Epoch 5/100
# 48/48 [==============================] - 0s 6ms/step - loss: 6.7838e-04
# Epoch 6/100
# 48/48 [==============================] - 0s 6ms/step - loss: 5.4137e-04
# Epoch 7/100
# 48/48 [==============================] - 0s 6ms/step - loss: 4.6499e-04
# Epoch 8/100
# 48/48 [==============================] - 0s 6ms/step - loss: 4.0815e-04
# Epoch 9/100
# 48/48 [==============================] - 0s 6ms/step - loss: 3.5780e-04
# Epoch 10/100
# 48/48 [==============================] - 0s 6ms/step - loss: 3.0703e-04
# Epoch 11/100
# 48/48 [==============================] - 0s 6ms/step - loss: 2.5930e-04
# Epoch 12/100
# 48/48 [==============================] - 0s 6ms/step - loss: 2.2364e-04
# Epoch 13/100
# 48/48 [==============================] - 0s 6ms/step - loss: 1.9397e-04
# Epoch 14/100
# 48/48 [==============================] - 0s 6ms/step - loss: 1.6775e-04
# Epoch 15/100
# 48/48 [==============================] - 0s 6ms/step - loss: 1.4728e-04
# Epoch 16/100
# 48/48 [==============================] - 0s 6ms/step - loss: 1.3027e-04
# Epoch 17/100
# 48/48 [==============================] - 0s 8ms/step - loss: 1.1778e-04
# Epoch 18/100
# 48/48 [==============================] - 0s 9ms/step - loss: 1.0864e-04
# Epoch 19/100
# 48/48 [==============================] - 0s 6ms/step - loss: 1.0030e-04
# Epoch 20/100
# 48/48 [==============================] - 0s 6ms/step - loss: 9.4786e-05
# Epoch 21/100
# 48/48 [==============================] - 0s 6ms/step - loss: 9.2816e-05
# Epoch 22/100
# 48/48 [==============================] - 0s 6ms/step - loss: 9.0719e-05
# Epoch 23/100
# 48/48 [==============================] - 0s 5ms/step - loss: 8.9723e-05
# Epoch 24/100
# 48/48 [==============================] - 0s 6ms/step - loss: 8.9911e-05
# Epoch 25/100
# 48/48 [==============================] - 0s 8ms/step - loss: 8.8126e-05
# Epoch 26/100
# 48/48 [==============================] - 0s 6ms/step - loss: 8.9266e-05
# Epoch 27/100
# 48/48 [==============================] - 0s 6ms/step - loss: 8.8651e-05
# Epoch 28/100
# 48/48 [==============================] - 0s 6ms/step - loss: 8.8658e-05
# Epoch 29/100
# 48/48 [==============================] - 0s 6ms/step - loss: 8.8149e-05
# Epoch 30/100
# 48/48 [==============================] - 0s 6ms/step - loss: 9.0454e-05
# Epoch 31/100
# 48/48 [==============================] - 0s 8ms/step - loss: 8.9161e-05
# Epoch 32/100
# 48/48 [==============================] - 0s 6ms/step - loss: 8.9610e-05
# Epoch 33/100
# 48/48 [==============================] - 0s 6ms/step - loss: 8.7355e-05
# Epoch 34/100
# 48/48 [==============================] - 0s 6ms/step - loss: 8.8368e-05
# Epoch 35/100
# 48/48 [==============================] - 0s 6ms/step - loss: 8.7679e-05
# Epoch 36/100
# 48/48 [==============================] - 0s 6ms/step - loss: 8.9006e-05
# Epoch 37/100
# 48/48 [==============================] - 0s 5ms/step - loss: 8.9113e-05
# Epoch 38/100
# 48/48 [==============================] - 0s 6ms/step - loss: 8.7439e-05
# Epoch 39/100
# 48/48 [==============================] - 0s 6ms/step - loss: 8.9778e-05
# Epoch 40/100
# 48/48 [==============================] - 0s 6ms/step - loss: 8.7004e-05
# Epoch 41/100
# 48/48 [==============================] - 0s 6ms/step - loss: 8.8071e-05
# Epoch 42/100
# 48/48 [==============================] - 0s 9ms/step - loss: 8.5825e-05
# Epoch 43/100
# 48/48 [==============================] - 0s 6ms/step - loss: 8.8584e-05
# Epoch 44/100
# 48/48 [==============================] - 0s 6ms/step - loss: 8.9065e-05
# Epoch 45/100
# 48/48 [==============================] - 0s 6ms/step - loss: 8.6657e-05
# Epoch 46/100
# 48/48 [==============================] - 0s 8ms/step - loss: 8.7359e-05
# Epoch 47/100
# 48/48 [==============================] - 0s 6ms/step - loss: 8.7374e-05
# Epoch 48/100
# 48/48 [==============================] - 0s 6ms/step - loss: 8.6499e-05
# Epoch 49/100
# 48/48 [==============================] - 0s 6ms/step - loss: 8.6360e-05
# Epoch 50/100
# 48/48 [==============================] - 0s 6ms/step - loss: 9.0855e-05
# Epoch 51/100
# 48/48 [==============================] - 0s 6ms/step - loss: 8.8228e-05
# Epoch 52/100
# 48/48 [==============================] - 0s 6ms/step - loss: 8.7153e-05
# Epoch 53/100
# 48/48 [==============================] - 0s 9ms/step - loss: 8.6861e-05
# Epoch 54/100
# 48/48 [==============================] - 0s 6ms/step - loss: 8.6732e-05
# Epoch 55/100
# 48/48 [==============================] - 0s 5ms/step - loss: 8.8576e-05
# Epoch 56/100
# 48/48 [==============================] - 0s 6ms/step - loss: 8.9647e-05
# Epoch 57/100
# 48/48 [==============================] - 0s 5ms/step - loss: 8.6918e-05
# Epoch 58/100
# 48/48 [==============================] - 0s 6ms/step - loss: 8.8499e-05
# Epoch 59/100
# 48/48 [==============================] - 0s 6ms/step - loss: 8.8126e-05
# Epoch 60/100
# 48/48 [==============================] - 0s 6ms/step - loss: 8.6545e-05
# Epoch 61/100
# 48/48 [==============================] - 0s 6ms/step - loss: 8.6651e-05
# Epoch 62/100
# 48/48 [==============================] - 0s 6ms/step - loss: 8.6156e-05
# Epoch 63/100
# 48/48 [==============================] - 0s 6ms/step - loss: 8.6500e-05
# Epoch 64/100
# 48/48 [==============================] - 0s 6ms/step - loss: 8.6925e-05
# Epoch 65/100
# 48/48 [==============================] - 0s 6ms/step - loss: 8.7528e-05
# Epoch 66/100
# 48/48 [==============================] - 0s 8ms/step - loss: 8.8633e-05
# Epoch 67/100
# 48/48 [==============================] - 0s 6ms/step - loss: 8.6538e-05
# Epoch 68/100
# 48/48 [==============================] - 0s 6ms/step - loss: 8.5585e-05
# Epoch 69/100
# 48/48 [==============================] - 0s 6ms/step - loss: 8.5822e-05
# Epoch 70/100
# 48/48 [==============================] - 0s 9ms/step - loss: 8.8373e-05
# Epoch 71/100
# 48/48 [==============================] - 0s 6ms/step - loss: 8.7578e-05
# Epoch 72/100
# 48/48 [==============================] - 0s 6ms/step - loss: 8.8489e-05
# Epoch 73/100
# 48/48 [==============================] - 0s 6ms/step - loss: 8.8507e-05
# Epoch 74/100
# 48/48 [==============================] - 0s 6ms/step - loss: 8.5055e-05
# Epoch 75/100
# 48/48 [==============================] - 0s 6ms/step - loss: 8.5679e-05
# Epoch 76/100
# 48/48 [==============================] - 0s 6ms/step - loss: 8.5611e-05
# Epoch 77/100
# 48/48 [==============================] - 0s 6ms/step - loss: 8.5870e-05
# Epoch 78/100
# 48/48 [==============================] - 0s 6ms/step - loss: 9.0840e-05
# Epoch 79/100
# 48/48 [==============================] - 0s 6ms/step - loss: 8.7636e-05
# Epoch 80/100
# 48/48 [==============================] - 0s 7ms/step - loss: 8.6996e-05
# Epoch 81/100
# 48/48 [==============================] - 0s 7ms/step - loss: 8.6518e-05
# Epoch 82/100
# 48/48 [==============================] - 0s 8ms/step - loss: 8.7419e-05
# Epoch 83/100
# 48/48 [==============================] - 0s 6ms/step - loss: 8.8492e-05
# Epoch 84/100
# 48/48 [==============================] - 0s 6ms/step - loss: 8.6990e-05
# Epoch 85/100
# 48/48 [==============================] - 0s 6ms/step - loss: 8.5413e-05
# Epoch 86/100
# 48/48 [==============================] - 0s 6ms/step - loss: 8.7618e-05
# Epoch 87/100
# 48/48 [==============================] - 0s 6ms/step - loss: 8.5681e-05
# Epoch 88/100
# 48/48 [==============================] - 0s 6ms/step - loss: 8.6142e-05
# Epoch 89/100
# 48/48 [==============================] - 0s 6ms/step - loss: 8.6650e-05
# Epoch 90/100
# 48/48 [==============================] - 0s 6ms/step - loss: 8.9451e-05
# Epoch 91/100
# 48/48 [==============================] - 0s 6ms/step - loss: 8.7328e-05
# Epoch 92/100
# 48/48 [==============================] - 0s 6ms/step - loss: 8.6786e-05
# Epoch 93/100
# 48/48 [==============================] - 0s 5ms/step - loss: 8.5571e-05
# Epoch 94/100
# 48/48 [==============================] - 0s 8ms/step - loss: 8.8122e-05
# Epoch 95/100
# 48/48 [==============================] - 0s 8ms/step - loss: 8.7292e-05
# Epoch 96/100
# 48/48 [==============================] - 0s 6ms/step - loss: 8.7088e-05
# Epoch 97/100
# 48/48 [==============================] - 0s 6ms/step - loss: 8.7744e-05
# Epoch 98/100
# 48/48 [==============================] - 0s 6ms/step - loss: 8.7971e-05
# Epoch 99/100
# 48/48 [==============================] - 0s 6ms/step - loss: 8.6507e-05
# Epoch 100/100
# 48/48 [==============================] - 0s 6ms/step - loss: 8.6847e-05

# %%
predictions = model.predict(X_test.reshape((-1,9,1)))

# %%
  
result= [i[8]for i in predictions]

result_2 = np.array(result)
print(result_2.shape)
# Out:
# (645, 2)

# %%
 # Create a DataFrame of Real and Predicted values
eth_eval = pd.DataFrame({
    "Actual": result_2.transpose()[0],
    "Predicted": result_2.transpose()[1]
}) 

# Show the DataFrame's head
eth_eval
# Out:
#        Actual  Predicted
# 0    0.045836   0.045953
# 1    0.045192   0.045304
# 2    0.046027   0.046134
# 3    0.045834   0.045943
# 4    0.045239   0.045347
# ..        ...        ...
# 640  0.413015   0.415217
# 641  0.403456   0.405421
# 642  0.433486   0.436372
# 643  0.441351   0.444614
# 644  0.455337   0.458882
#
# [645 rows x 2 columns]

# %%
eth_eval.plot(title="Actual Vs. Predicted ETH Prices")
# Out:
# <AxesSubplot:title={'center':'Actual Vs. Predicted ETH Prices'}>

# %%
main_df.plot(title="Actual Vs. Predicted ETH Prices")
# Out:
# <AxesSubplot:title={'center':'Actual Vs. Predicted ETH Prices'}, xlabel='Date'>
