# %%
# Initial imports
import numpy as np
import pandas as pd
from pathlib import Path

# %matplotlib inline

# %%
 # Set path to CSV and read in CSV
csv_path = Path("DATA/DOGE/DOGE_DATA.csv")
doge_df=pd.read_csv(csv_path)

# %%
 # Set index as Date
doge_df = doge_df.set_index(pd.to_datetime(doge_df["Date"], infer_datetime_format=True))

# Display sample data
doge_df.head(10)
# Out:
#            Currency        Date  Closing Price (USD)  24h Open (USD)  \
# Date
# 2019-02-27     DOGE  2019-02-27             0.001944        0.001962
# 2019-02-28     DOGE  2019-02-28             0.001912        0.001944
# 2019-03-01     DOGE  2019-03-01             0.001956        0.001912
# 2019-03-02     DOGE  2019-03-02             0.001970        0.001957
# 2019-03-03     DOGE  2019-03-03             0.001948        0.001970
# 2019-03-04     DOGE  2019-03-04             0.001900        0.001948
# 2019-03-05     DOGE  2019-03-05             0.001939        0.001902
# 2019-03-06     DOGE  2019-03-06             0.001931        0.001939
# 2019-03-07     DOGE  2019-03-07             0.001944        0.001931
# 2019-03-08     DOGE  2019-03-08             0.001926        0.001944
#
#             24h High (USD)  24h Low (USD)
# Date
# 2019-02-27        0.001963       0.001908
# 2019-02-28        0.001955       0.001896
# 2019-03-01        0.001977       0.001911
# 2019-03-02        0.001980       0.001940
# 2019-03-03        0.001989       0.001940
# 2019-03-04        0.001960       0.001893
# 2019-03-05        0.001964       0.001891
# 2019-03-06        0.001961       0.001919
# 2019-03-07        0.001990       0.001927
# 2019-03-08        0.001966       0.001909

# %%
#check for na
doge_df.isnull().values.any()
# Out:
# False

# %%
# Set the random seed to (2)
from numpy.random import seed

seed(1)
from tensorflow import random

random.set_seed(2)

# %%
def window_data(df, window, feature_col_number, target_col_number):
    X = []
    y = []
    for i in range(len(df) - window):
        features = df.iloc[i : (i + window), feature_col_number]
        target = df.iloc[(i + window), target_col_number]
        X.append(features)
        y.append(target)
    return np.array(X), np.array(y).reshape(-1, 1)

# %%
# Define the window size
window_size = 100

# Set the index of the feature and target columns
feature_column = 2
target_column = 2

# Create the features (X) and target (y) data using the window_data() function.
X, y = window_data(doge_df, window_size, feature_column, target_column)

# Print a few sample values from X and y
print (f"X sample values:\n{X[:3]} \n")
print (f"y sample values:\n{y[:3]}")
# Out:
# X sample values:
# [[0.00194413 0.00191243 0.00195579 0.00196963 0.00194837 0.0018997
#   0.0019386  0.00193116 0.0019439  0.00192575 0.00195179 0.00195127
#   0.0019291  0.00199423 0.0019794  0.00201348 0.00202135 0.00204606
#   0.0020523  0.00204451 0.00204142 0.00202512 0.00202262 0.00200737
#   0.00200919 0.00200528 0.00201154 0.00203147 0.00205462 0.00204445
#   0.00208126 0.00207596 0.00206667 0.00241034 0.00292721 0.003173
#   0.00364039 0.00352948 0.00336789 0.00339882 0.00294825 0.00287584
#   0.00296385 0.00274343 0.00281366 0.0028431  0.00286845 0.00274786
#   0.00277609 0.0027763  0.00295894 0.00289124 0.00285828 0.00275998
#   0.00276394 0.00276767 0.00256035 0.00241539 0.00252244 0.00253833
#   0.00243369 0.00241323 0.00248825 0.00245055 0.00254029 0.00267698
#   0.00267155 0.0025769  0.00256247 0.00252779 0.00253745 0.00246249
#   0.00254303 0.00275622 0.00263807 0.00272007 0.00301285 0.00328175
#   0.00319722 0.00289653 0.00299698 0.00312798 0.00297548 0.00304195
#   0.00291579 0.00295498 0.00301222 0.0030586  0.00304516 0.0031297
#   0.00315526 0.00321008 0.00321412 0.00340477 0.00336021 0.00332395
#   0.00322468 0.00297652 0.00302772 0.00301459]
#  [0.00191243 0.00195579 0.00196963 0.00194837 0.0018997  0.0019386
#   0.00193116 0.0019439  0.00192575 0.00195179 0.00195127 0.0019291
#   0.00199423 0.0019794  0.00201348 0.00202135 0.00204606 0.0020523
#   0.00204451 0.00204142 0.00202512 0.00202262 0.00200737 0.00200919
#   0.00200528 0.00201154 0.00203147 0.00205462 0.00204445 0.00208126
#   0.00207596 0.00206667 0.00241034 0.00292721 0.003173   0.00364039
#   0.00352948 0.00336789 0.00339882 0.00294825 0.00287584 0.00296385
#   0.00274343 0.00281366 0.0028431  0.00286845 0.00274786 0.00277609
#   0.0027763  0.00295894 0.00289124 0.00285828 0.00275998 0.00276394
#   0.00276767 0.00256035 0.00241539 0.00252244 0.00253833 0.00243369
#   0.00241323 0.00248825 0.00245055 0.00254029 0.00267698 0.00267155
#   0.0025769  0.00256247 0.00252779 0.00253745 0.00246249 0.00254303
#   0.00275622 0.00263807 0.00272007 0.00301285 0.00328175 0.00319722
#   0.00289653 0.00299698 0.00312798 0.00297548 0.00304195 0.00291579
#   0.00295498 0.00301222 0.0030586  0.00304516 0.0031297  0.00315526
#   0.00321008 0.00321412 0.00340477 0.00336021 0.00332395 0.00322468
#   0.00297652 0.00302772 0.00301459 0.00312935]
#  [0.00195579 0.00196963 0.00194837 0.0018997  0.0019386  0.00193116
#   0.0019439  0.00192575 0.00195179 0.00195127 0.0019291  0.00199423
#   0.0019794  0.00201348 0.00202135 0.00204606 0.0020523  0.00204451
#   0.00204142 0.00202512 0.00202262 0.00200737 0.00200919 0.00200528
#   0.00201154 0.00203147 0.00205462 0.00204445 0.00208126 0.00207596
#   0.00206667 0.00241034 0.00292721 0.003173   0.00364039 0.00352948
#   0.00336789 0.00339882 0.00294825 0.00287584 0.00296385 0.00274343
#   0.00281366 0.0028431  0.00286845 0.00274786 0.00277609 0.0027763
#   0.00295894 0.00289124 0.00285828 0.00275998 0.00276394 0.00276767
#   0.00256035 0.00241539 0.00252244 0.00253833 0.00243369 0.00241323
#   0.00248825 0.00245055 0.00254029 0.00267698 0.00267155 0.0025769
#   0.00256247 0.00252779 0.00253745 0.00246249 0.00254303 0.00275622
#   0.00263807 0.00272007 0.00301285 0.00328175 0.00319722 0.00289653
#   0.00299698 0.00312798 0.00297548 0.00304195 0.00291579 0.00295498
#   0.00301222 0.0030586  0.00304516 0.0031297  0.00315526 0.00321008
#   0.00321412 0.00340477 0.00336021 0.00332395 0.00322468 0.00297652
#   0.00302772 0.00301459 0.00312935 0.00302067]]
#
# y sample values:
# [[0.00312935]
#  [0.00302067]
#  [0.00295865]]

# %%
 # Manually splitting the data
split = int(0.7 * len(X))

X_train = X[: split]
X_test = X[split:]

y_train = y[: split]
y_test = y[split:]

# %%
 # Importing the MinMaxScaler from sklearn
from sklearn.preprocessing import MinMaxScaler

# Create a MinMaxScaler object
scaler = MinMaxScaler()

# Fit the MinMaxScaler object with the features data X
scaler.fit(X)

# Scale the features training and testing sets
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# Fit the MinMaxScaler object with the target data Y
scaler.fit(y)

# Scale the target training and testing sets
y_train = scaler.transform(y_train)
y_test = scaler.transform(y_test)

# %%
 # Reshape the features data
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# Print some sample data after reshaping the datasets
print (f"X_train sample values:\n{X_train[:3]} \n")
print (f"X_test sample values:\n{X_test[:3]}")
# Out:
# X_train sample values:
# [[[0.00095741]
#   [0.00079557]
#   [0.00090006]
#   [0.0009334 ]
#   [0.00088217]
#   [0.0007649 ]
#   [0.00085863]
#   [0.00084071]
#   [0.00087141]
#   [0.00082767]
#   [0.00089042]
#   [0.00088917]
#   [0.00083574]
#   [0.00099269]
#   [0.00095696]
#   [0.00099162]
#   [0.00081167]
#   [0.00072461]
#   [0.00073436]
#   [0.00064131]
#   [0.00063701]
#   [0.0006144 ]
#   [0.00061093]
#   [0.00058978]
#   [0.00059231]
#   [0.00058688]
#   [0.00059556]
#   [0.00062321]
#   [0.00065533]
#   [0.00064122]
#   [0.0006923 ]
#   [0.00068494]
#   [0.00067206]
#   [0.00114888]
#   [0.00186603]
#   [0.00220706]
#   [0.00285553]
#   [0.00270165]
#   [0.00247745]
#   [0.00252036]
#   [0.00189522]
#   [0.00179475]
#   [0.00191687]
#   [0.00161104]
#   [0.00170848]
#   [0.00174932]
#   [0.0017845 ]
#   [0.00161719]
#   [0.00165635]
#   [0.00165665]
#   [0.00191006]
#   [0.00181612]
#   [0.00177039]
#   [0.001634  ]
#   [0.00163949]
#   [0.00164467]
#   [0.00135702]
#   [0.00115589]
#   [0.00130442]
#   [0.00132646]
#   [0.00118129]
#   [0.00115289]
#   [0.00125698]
#   [0.00120467]
#   [0.00132919]
#   [0.00151884]
#   [0.0015113 ]
#   [0.00137998]
#   [0.00135996]
#   [0.00131184]
#   [0.00132525]
#   [0.00122125]
#   [0.00133298]
#   [0.00162878]
#   [0.00146485]
#   [0.00157863]
#   [0.00198485]
#   [0.00235793]
#   [0.00224065]
#   [0.00182346]
#   [0.00196283]
#   [0.00214458]
#   [0.00193299]
#   [0.00202522]
#   [0.00185018]
#   [0.00190455]
#   [0.00198398]
#   [0.00204833]
#   [0.00202968]
#   [0.00214697]
#   [0.00218244]
#   [0.0022585 ]
#   [0.0022641 ]
#   [0.00252862]
#   [0.0024668 ]
#   [0.00241649]
#   [0.00227876]
#   [0.00193444]
#   [0.00200547]
#   [0.00198727]]
#
#  [[0.00087352]
#   [0.00090006]
#   [0.0009334 ]
#   [0.00088217]
#   [0.0007649 ]
#   [0.00085863]
#   [0.00084071]
#   [0.00087141]
#   [0.00082767]
#   [0.00089042]
#   [0.00088917]
#   [0.00083574]
#   [0.00099269]
#   [0.00095696]
#   [0.00103909]
#   [0.00100971]
#   [0.00085735]
#   [0.00073436]
#   [0.00072219]
#   [0.00063701]
#   [0.0006144 ]
#   [0.00061093]
#   [0.00058978]
#   [0.00059231]
#   [0.00058688]
#   [0.00059556]
#   [0.00062321]
#   [0.00065533]
#   [0.00064122]
#   [0.0006923 ]
#   [0.00068494]
#   [0.00067206]
#   [0.00114888]
#   [0.00186603]
#   [0.00220706]
#   [0.00285553]
#   [0.00270165]
#   [0.00247745]
#   [0.00252036]
#   [0.00189522]
#   [0.00179475]
#   [0.00191687]
#   [0.00161104]
#   [0.00170848]
#   [0.00174932]
#   [0.0017845 ]
#   [0.00161719]
#   [0.00165635]
#   [0.00165665]
#   [0.00191006]
#   [0.00181612]
#   [0.00177039]
#   [0.001634  ]
#   [0.00163949]
#   [0.00164467]
#   [0.00135702]
#   [0.00115589]
#   [0.00130442]
#   [0.00132646]
#   [0.00118129]
#   [0.00115289]
#   [0.00125698]
#   [0.00120467]
#   [0.00132919]
#   [0.00151884]
#   [0.0015113 ]
#   [0.00137998]
#   [0.00135996]
#   [0.00131184]
#   [0.00132525]
#   [0.00122125]
#   [0.00133298]
#   [0.00162878]
#   [0.00146485]
#   [0.00157863]
#   [0.00198485]
#   [0.00235793]
#   [0.00224065]
#   [0.00182346]
#   [0.00196283]
#   [0.00214458]
#   [0.00193299]
#   [0.00202522]
#   [0.00185018]
#   [0.00190455]
#   [0.00198398]
#   [0.00204833]
#   [0.00202968]
#   [0.00214697]
#   [0.00218244]
#   [0.0022585 ]
#   [0.0022641 ]
#   [0.00252862]
#   [0.0024668 ]
#   [0.00241649]
#   [0.00227876]
#   [0.00193444]
#   [0.00200547]
#   [0.00198727]
#   [0.00214649]]
#
#  [[0.00098825]
#   [0.0009334 ]
#   [0.00088217]
#   [0.0007649 ]
#   [0.00085863]
#   [0.00084071]
#   [0.00087141]
#   [0.00082767]
#   [0.00089042]
#   [0.00088917]
#   [0.00083574]
#   [0.00099269]
#   [0.00095696]
#   [0.00103909]
#   [0.00105805]
#   [0.00106653]
#   [0.00086889]
#   [0.00072219]
#   [0.00071735]
#   [0.0006144 ]
#   [0.00061093]
#   [0.00058978]
#   [0.00059231]
#   [0.00058688]
#   [0.00059556]
#   [0.00062321]
#   [0.00065533]
#   [0.00064122]
#   [0.0006923 ]
#   [0.00068494]
#   [0.00067206]
#   [0.00114888]
#   [0.00186603]
#   [0.00220706]
#   [0.00285553]
#   [0.00270165]
#   [0.00247745]
#   [0.00252036]
#   [0.00189522]
#   [0.00179475]
#   [0.00191687]
#   [0.00161104]
#   [0.00170848]
#   [0.00174932]
#   [0.0017845 ]
#   [0.00161719]
#   [0.00165635]
#   [0.00165665]
#   [0.00191006]
#   [0.00181612]
#   [0.00177039]
#   [0.001634  ]
#   [0.00163949]
#   [0.00164467]
#   [0.00135702]
#   [0.00115589]
#   [0.00130442]
#   [0.00132646]
#   [0.00118129]
#   [0.00115289]
#   [0.00125698]
#   [0.00120467]
#   [0.00132919]
#   [0.00151884]
#   [0.0015113 ]
#   [0.00137998]
#   [0.00135996]
#   [0.00131184]
#   [0.00132525]
#   [0.00122125]
#   [0.00133298]
#   [0.00162878]
#   [0.00146485]
#   [0.00157863]
#   [0.00198485]
#   [0.00235793]
#   [0.00224065]
#   [0.00182346]
#   [0.00196283]
#   [0.00214458]
#   [0.00193299]
#   [0.00202522]
#   [0.00185018]
#   [0.00190455]
#   [0.00198398]
#   [0.00204833]
#   [0.00202968]
#   [0.00214697]
#   [0.00218244]
#   [0.0022585 ]
#   [0.0022641 ]
#   [0.00252862]
#   [0.0024668 ]
#   [0.00241649]
#   [0.00227876]
#   [0.00193444]
#   [0.00200547]
#   [0.00198727]
#   [0.00214649]
#   [0.00199569]]]
#
# X_test sample values:
# [[[0.00422623]
#   [0.00401392]
#   [0.00409348]
#   [0.00414991]
#   [0.00390717]
#   [0.00399483]
#   [0.00369782]
#   [0.00322743]
#   [0.00321949]
#   [0.00276663]
#   [0.00284375]
#   [0.00302809]
#   [0.00274925]
#   [0.0029416 ]
#   [0.00293053]
#   [0.00279053]
#   [0.00223275]
#   [0.0018476 ]
#   [0.00187459]
#   [0.00172265]
#   [0.00167742]
#   [0.00167968]
#   [0.00168643]
#   [0.00167665]
#   [0.00162358]
#   [0.00150372]
#   [0.00143726]
#   [0.00135483]
#   [0.00145763]
#   [0.00153087]
#   [0.00155447]
#   [0.00155858]
#   [0.00150554]
#   [0.00151491]
#   [0.0014507 ]
#   [0.00145566]
#   [0.00141401]
#   [0.00138987]
#   [0.00142905]
#   [0.00142118]
#   [0.00140703]
#   [0.00139517]
#   [0.00144128]
#   [0.00148738]
#   [0.00153601]
#   [0.00153238]
#   [0.001567  ]
#   [0.0014707 ]
#   [0.0014846 ]
#   [0.00142344]
#   [0.00139633]
#   [0.00136537]
#   [0.00140539]
#   [0.00140163]
#   [0.0014071 ]
#   [0.00152492]
#   [0.00152229]
#   [0.00149464]
#   [0.00148856]
#   [0.00152605]
#   [0.00150283]
#   [0.00154468]
#   [0.00135652]
#   [0.00139229]
#   [0.0013973 ]
#   [0.00141856]
#   [0.00137876]
#   [0.00127808]
#   [0.00128022]
#   [0.00134806]
#   [0.00152204]
#   [0.00156484]
#   [0.0015176 ]
#   [0.00153561]
#   [0.00152379]
#   [0.00175222]
#   [0.00162188]
#   [0.00165739]
#   [0.00172225]
#   [0.00164206]
#   [0.00166503]
#   [0.00179949]
#   [0.00185256]
#   [0.00188496]
#   [0.00183347]
#   [0.00204109]
#   [0.00264644]
#   [0.00256659]
#   [0.00258808]
#   [0.00327053]
#   [0.00297116]
#   [0.00232728]
#   [0.0023741 ]
#   [0.00256369]
#   [0.00256679]
#   [0.00275756]
#   [0.00250072]
#   [0.00248865]
#   [0.00251475]
#   [0.00241427]]
#
#  [[0.00440722]
#   [0.00409348]
#   [0.00414991]
#   [0.00390717]
#   [0.00399483]
#   [0.00369782]
#   [0.00322743]
#   [0.00321949]
#   [0.00276663]
#   [0.00284375]
#   [0.00302809]
#   [0.00274925]
#   [0.0029416 ]
#   [0.00293053]
#   [0.00292412]
#   [0.00277752]
#   [0.00218606]
#   [0.00187459]
#   [0.0019399 ]
#   [0.00167742]
#   [0.00167968]
#   [0.00168643]
#   [0.00167665]
#   [0.00162358]
#   [0.00150372]
#   [0.00143726]
#   [0.00135483]
#   [0.00145763]
#   [0.00153087]
#   [0.00155447]
#   [0.00155858]
#   [0.00150554]
#   [0.00151491]
#   [0.0014507 ]
#   [0.00145566]
#   [0.00141401]
#   [0.00138987]
#   [0.00142905]
#   [0.00142118]
#   [0.00140703]
#   [0.00139517]
#   [0.00144128]
#   [0.00148738]
#   [0.00153601]
#   [0.00153238]
#   [0.001567  ]
#   [0.0014707 ]
#   [0.0014846 ]
#   [0.00142344]
#   [0.00139633]
#   [0.00136537]
#   [0.00140539]
#   [0.00140163]
#   [0.0014071 ]
#   [0.00152492]
#   [0.00152229]
#   [0.00149464]
#   [0.00148856]
#   [0.00152605]
#   [0.00150283]
#   [0.00154468]
#   [0.00135652]
#   [0.00139229]
#   [0.0013973 ]
#   [0.00141856]
#   [0.00137876]
#   [0.00127808]
#   [0.00128022]
#   [0.00134806]
#   [0.00152204]
#   [0.00156484]
#   [0.0015176 ]
#   [0.00153561]
#   [0.00152379]
#   [0.00175222]
#   [0.00162188]
#   [0.00165739]
#   [0.00172225]
#   [0.00164206]
#   [0.00166503]
#   [0.00179949]
#   [0.00185256]
#   [0.00188496]
#   [0.00183347]
#   [0.00204109]
#   [0.00264644]
#   [0.00256659]
#   [0.00258808]
#   [0.00327053]
#   [0.00297116]
#   [0.00232728]
#   [0.0023741 ]
#   [0.00256369]
#   [0.00256679]
#   [0.00275756]
#   [0.00250072]
#   [0.00248865]
#   [0.00251475]
#   [0.00241427]
#   [0.00252382]]
#
#  [[0.00449457]
#   [0.00414991]
#   [0.00390717]
#   [0.00399483]
#   [0.00369782]
#   [0.00322743]
#   [0.00321949]
#   [0.00276663]
#   [0.00284375]
#   [0.00302809]
#   [0.00274925]
#   [0.0029416 ]
#   [0.00293053]
#   [0.00292412]
#   [0.00291049]
#   [0.00271944]
#   [0.002218  ]
#   [0.0019399 ]
#   [0.00188897]
#   [0.00167968]
#   [0.00168643]
#   [0.00167665]
#   [0.00162358]
#   [0.00150372]
#   [0.00143726]
#   [0.00135483]
#   [0.00145763]
#   [0.00153087]
#   [0.00155447]
#   [0.00155858]
#   [0.00150554]
#   [0.00151491]
#   [0.0014507 ]
#   [0.00145566]
#   [0.00141401]
#   [0.00138987]
#   [0.00142905]
#   [0.00142118]
#   [0.00140703]
#   [0.00139517]
#   [0.00144128]
#   [0.00148738]
#   [0.00153601]
#   [0.00153238]
#   [0.001567  ]
#   [0.0014707 ]
#   [0.0014846 ]
#   [0.00142344]
#   [0.00139633]
#   [0.00136537]
#   [0.00140539]
#   [0.00140163]
#   [0.0014071 ]
#   [0.00152492]
#   [0.00152229]
#   [0.00149464]
#   [0.00148856]
#   [0.00152605]
#   [0.00150283]
#   [0.00154468]
#   [0.00135652]
#   [0.00139229]
#   [0.0013973 ]
#   [0.00141856]
#   [0.00137876]
#   [0.00127808]
#   [0.00128022]
#   [0.00134806]
#   [0.00152204]
#   [0.00156484]
#   [0.0015176 ]
#   [0.00153561]
#   [0.00152379]
#   [0.00175222]
#   [0.00162188]
#   [0.00165739]
#   [0.00172225]
#   [0.00164206]
#   [0.00166503]
#   [0.00179949]
#   [0.00185256]
#   [0.00188496]
#   [0.00183347]
#   [0.00204109]
#   [0.00264644]
#   [0.00256659]
#   [0.00258808]
#   [0.00327053]
#   [0.00297116]
#   [0.00232728]
#   [0.0023741 ]
#   [0.00256369]
#   [0.00256679]
#   [0.00275756]
#   [0.00250072]
#   [0.00248865]
#   [0.00251475]
#   [0.00241427]
#   [0.00252382]
#   [0.00250272]]]

# %%
 # Importing required Keras modules
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# %%
# Define the LSTM RNN model.
model = Sequential()

# Initial model setup
number_units = 100
dropout_fraction = 0.2

# Layer 1
model.add(LSTM(
    units=number_units,
    return_sequences=True,
    input_shape=(X_train.shape[1], 1))
    )
model.add(Dropout(dropout_fraction))

# Layer 2
model.add(LSTM(units=number_units, return_sequences=True))
model.add(Dropout(dropout_fraction))

# Layer 3
model.add(LSTM(units=number_units))
model.add(Dropout(dropout_fraction))

# Output layer
model.add(Dense(1))

# %%
 # Compile the model
model.compile(optimizer="adam", loss="mean_squared_error")

# %%
# Show the model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100, 100)          40800
# _________________________________________________________________
# dropout (Dropout)            (None, 100, 100)          0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 100, 100)          80400
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100, 100)          0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 100)               80400
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 201,701
# Trainable params: 201,701
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model
model.fit(X_train, y_train, epochs=100, shuffle=False, batch_size=90, verbose=1)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 7s 34ms/step - loss: 1.9485e-04
# Epoch 2/100
# 7/7 [==============================] - 0s 25ms/step - loss: 5.0307e-05
# Epoch 3/100
# 7/7 [==============================] - 0s 26ms/step - loss: 1.4012e-05
# Epoch 4/100
# 7/7 [==============================] - 0s 22ms/step - loss: 7.0481e-06
# Epoch 5/100
# 7/7 [==============================] - 0s 24ms/step - loss: 3.0663e-06
# Epoch 6/100
# 7/7 [==============================] - 0s 23ms/step - loss: 2.7972e-06
# Epoch 7/100
# 7/7 [==============================] - 0s 23ms/step - loss: 1.2103e-06
# Epoch 8/100
# 7/7 [==============================] - 0s 21ms/step - loss: 1.5879e-06
# Epoch 9/100
# 7/7 [==============================] - 0s 22ms/step - loss: 7.3765e-07
# Epoch 10/100
# 7/7 [==============================] - 0s 23ms/step - loss: 1.0646e-06
# Epoch 11/100
# 7/7 [==============================] - 0s 21ms/step - loss: 6.1899e-07
# Epoch 12/100
# 7/7 [==============================] - 0s 21ms/step - loss: 8.2416e-07
# Epoch 13/100
# 7/7 [==============================] - 0s 22ms/step - loss: 6.5506e-07
# Epoch 14/100
# 7/7 [==============================] - 0s 22ms/step - loss: 6.6659e-07
# Epoch 15/100
# 7/7 [==============================] - 0s 22ms/step - loss: 7.8636e-07
# Epoch 16/100
# 7/7 [==============================] - 0s 22ms/step - loss: 7.3010e-07
# Epoch 17/100
# 7/7 [==============================] - 0s 22ms/step - loss: 8.1238e-07
# Epoch 18/100
# 7/7 [==============================] - 0s 24ms/step - loss: 7.4747e-07
# Epoch 19/100
# 7/7 [==============================] - 0s 22ms/step - loss: 6.5714e-07
# Epoch 20/100
# 7/7 [==============================] - 0s 24ms/step - loss: 7.3659e-07
# Epoch 21/100
# 7/7 [==============================] - 0s 22ms/step - loss: 9.1754e-07
# Epoch 22/100
# 7/7 [==============================] - 0s 22ms/step - loss: 7.4767e-07
# Epoch 23/100
# 7/7 [==============================] - 0s 22ms/step - loss: 8.0364e-07
# Epoch 24/100
# 7/7 [==============================] - 0s 22ms/step - loss: 8.1999e-07
# Epoch 25/100
# 7/7 [==============================] - 0s 23ms/step - loss: 7.6919e-07
# Epoch 26/100
# 7/7 [==============================] - 0s 23ms/step - loss: 8.8029e-07
# Epoch 27/100
# 7/7 [==============================] - 0s 23ms/step - loss: 8.1588e-07
# Epoch 28/100
# 7/7 [==============================] - 0s 22ms/step - loss: 8.6947e-07
# Epoch 29/100
# 7/7 [==============================] - 0s 23ms/step - loss: 9.4246e-07
# Epoch 30/100
# 7/7 [==============================] - 0s 24ms/step - loss: 7.8326e-07
# Epoch 31/100
# 7/7 [==============================] - 0s 23ms/step - loss: 9.6073e-07
# Epoch 32/100
# 7/7 [==============================] - 0s 24ms/step - loss: 9.1081e-07
# Epoch 33/100
# 7/7 [==============================] - 0s 24ms/step - loss: 8.9239e-07
# Epoch 34/100
# 7/7 [==============================] - 0s 22ms/step - loss: 8.0018e-07
# Epoch 35/100
# 7/7 [==============================] - 0s 23ms/step - loss: 8.8052e-07
# Epoch 36/100
# 7/7 [==============================] - 0s 23ms/step - loss: 9.8123e-07
# Epoch 37/100
# 7/7 [==============================] - 0s 23ms/step - loss: 1.0327e-06
# Epoch 38/100
# 7/7 [==============================] - 0s 24ms/step - loss: 9.4450e-07
# Epoch 39/100
# 7/7 [==============================] - 0s 23ms/step - loss: 9.1300e-07
# Epoch 40/100
# 7/7 [==============================] - 0s 22ms/step - loss: 9.8798e-07
# Epoch 41/100
# 7/7 [==============================] - 0s 23ms/step - loss: 9.5363e-07
# Epoch 42/100
# 7/7 [==============================] - 0s 24ms/step - loss: 9.3811e-07
# Epoch 43/100
# 7/7 [==============================] - 0s 24ms/step - loss: 9.7982e-07
# Epoch 44/100
# 7/7 [==============================] - 0s 24ms/step - loss: 9.0873e-07
# Epoch 45/100
# 7/7 [==============================] - 0s 25ms/step - loss: 1.0159e-06
# Epoch 46/100
# 7/7 [==============================] - 0s 25ms/step - loss: 1.1510e-06
# Epoch 47/100
# 7/7 [==============================] - 0s 22ms/step - loss: 8.7224e-07
# Epoch 48/100
# 7/7 [==============================] - 0s 24ms/step - loss: 1.0261e-06
# Epoch 49/100
# 7/7 [==============================] - 0s 23ms/step - loss: 1.2052e-06
# Epoch 50/100
# 7/7 [==============================] - 0s 22ms/step - loss: 1.0969e-06
# Epoch 51/100
# 7/7 [==============================] - 0s 23ms/step - loss: 1.0121e-06
# Epoch 52/100
# 7/7 [==============================] - 0s 25ms/step - loss: 1.0199e-06
# Epoch 53/100
# 7/7 [==============================] - 0s 22ms/step - loss: 1.0513e-06
# Epoch 54/100
# 7/7 [==============================] - 0s 22ms/step - loss: 9.8384e-07
# Epoch 55/100
# 7/7 [==============================] - 0s 21ms/step - loss: 9.3399e-07
# Epoch 56/100
# 7/7 [==============================] - 0s 24ms/step - loss: 9.8731e-07
# Epoch 57/100
# 7/7 [==============================] - 0s 25ms/step - loss: 1.0648e-06
# Epoch 58/100
# 7/7 [==============================] - 0s 24ms/step - loss: 1.0963e-06
# Epoch 59/100
# 7/7 [==============================] - 0s 23ms/step - loss: 9.7113e-07
# Epoch 60/100
# 7/7 [==============================] - 0s 23ms/step - loss: 1.2332e-06
# Epoch 61/100
# 7/7 [==============================] - 0s 23ms/step - loss: 1.2620e-06
# Epoch 62/100
# 7/7 [==============================] - 0s 24ms/step - loss: 1.0554e-06
# Epoch 63/100
# 7/7 [==============================] - 0s 22ms/step - loss: 1.0144e-06
# Epoch 64/100
# 7/7 [==============================] - 0s 22ms/step - loss: 1.0026e-06
# Epoch 65/100
# 7/7 [==============================] - 0s 24ms/step - loss: 1.2411e-06
# Epoch 66/100
# 7/7 [==============================] - 0s 22ms/step - loss: 1.0896e-06
# Epoch 67/100
# 7/7 [==============================] - 0s 22ms/step - loss: 9.0684e-07
# Epoch 68/100
# 7/7 [==============================] - 0s 28ms/step - loss: 1.2097e-06
# Epoch 69/100
# 7/7 [==============================] - 0s 34ms/step - loss: 1.2832e-06
# Epoch 70/100
# 7/7 [==============================] - 0s 25ms/step - loss: 1.1009e-06
# Epoch 71/100
# 7/7 [==============================] - 0s 31ms/step - loss: 1.0213e-06
# Epoch 72/100
# 7/7 [==============================] - 0s 24ms/step - loss: 1.1390e-06
# Epoch 73/100
# 7/7 [==============================] - 0s 33ms/step - loss: 1.1640e-06
# Epoch 74/100
# 7/7 [==============================] - 0s 22ms/step - loss: 1.2696e-06
# Epoch 75/100
# 7/7 [==============================] - 0s 34ms/step - loss: 1.1990e-06
# Epoch 76/100
# 7/7 [==============================] - 0s 25ms/step - loss: 1.0876e-06
# Epoch 77/100
# 7/7 [==============================] - 0s 30ms/step - loss: 1.0918e-06
# Epoch 78/100
# 7/7 [==============================] - 0s 29ms/step - loss: 1.1860e-06
# Epoch 79/100
# 7/7 [==============================] - 0s 23ms/step - loss: 1.0262e-06
# Epoch 80/100
# 7/7 [==============================] - 0s 36ms/step - loss: 1.0938e-06
# Epoch 81/100
# 7/7 [==============================] - 0s 31ms/step - loss: 1.1750e-06
# Epoch 82/100
# 7/7 [==============================] - 0s 35ms/step - loss: 1.0684e-06
# Epoch 83/100
# 7/7 [==============================] - 0s 23ms/step - loss: 1.0853e-06
# Epoch 84/100
# 7/7 [==============================] - 0s 34ms/step - loss: 9.9569e-07
# Epoch 85/100
# 7/7 [==============================] - 0s 24ms/step - loss: 1.0847e-06
# Epoch 86/100
# 7/7 [==============================] - 0s 34ms/step - loss: 1.1519e-06
# Epoch 87/100
# 7/7 [==============================] - 0s 22ms/step - loss: 1.3900e-06
# Epoch 88/100
# 7/7 [==============================] - 0s 22ms/step - loss: 1.4551e-06
# Epoch 89/100
# 7/7 [==============================] - 0s 22ms/step - loss: 1.5883e-06
# Epoch 90/100
# 7/7 [==============================] - 0s 32ms/step - loss: 1.6484e-06
# Epoch 91/100
# 7/7 [==============================] - 0s 22ms/step - loss: 1.3687e-06
# Epoch 92/100
# 7/7 [==============================] - 0s 32ms/step - loss: 1.1909e-06
# Epoch 93/100
# 7/7 [==============================] - 0s 29ms/step - loss: 1.4905e-06
# Epoch 94/100
# 7/7 [==============================] - 0s 27ms/step - loss: 1.3051e-06
# Epoch 95/100
# 7/7 [==============================] - 0s 33ms/step - loss: 1.3487e-06
# Epoch 96/100
# 7/7 [==============================] - 0s 24ms/step - loss: 1.4997e-06
# Epoch 97/100
# 7/7 [==============================] - 0s 31ms/step - loss: 1.2660e-06
# Epoch 98/100
# 7/7 [==============================] - 0s 27ms/step - loss: 1.1987e-06
# Epoch 99/100
# 7/7 [==============================] - 0s 28ms/step - loss: 1.1134e-06
# Epoch 100/100
# 7/7 [==============================] - 0s 22ms/step - loss: 1.0968e-06

# %%
 # Make predictions using the testing data X_test
predicted = model.predict(X_test)

# %%
predicted.shape
# Out:
# (235, 1)

# %%
# Recover the original prices instead of the scaled version
predicted_prices = scaler.inverse_transform(predicted)
real_prices = scaler.inverse_transform(y_test.reshape(-1, 1))

# %%
 # Create a DataFrame of Real and Predicted values
doge_eval = pd.DataFrame({
    "Actual": real_prices.ravel(),
    "Predicted": predicted_prices.ravel()
}, index = doge_df.index[-len(real_prices): ]) 

# Show the DataFrame's head
doge_eval.head()
# Out:
#               Actual  Predicted
# Date
# 2020-12-05  0.003401   0.002790
# 2020-12-06  0.003386   0.002789
# 2020-12-07  0.003320   0.002789
# 2020-12-08  0.003216   0.002788
# 2020-12-09  0.003213   0.002787

# %%
 # Plot the real vs predicted prices as a line chart
doge_eval.plot(title="Actual Vs. Predicted DOGE Prices")
# Out:
# <AxesSubplot:title={'center':'Actual Vs. Predicted DOGE Prices'}, xlabel='Date'>

# %%
#seprate actual and pred
Pred= doge_eval['Actual']
act= doge_eval['Predicted']

#model eval
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
import math
print(mean_squared_error(act, Pred))
print(math.sqrt(mean_squared_error(act, Pred)))
print(mean_absolute_error(act, Pred))
# Out:
# 0.04493850342206287
# 0.21198703597640792
# 0.14830022909149793

# %%
#create buy and sell signals 
#calculate profit and loss

#create 'profit/loss' column to track trade metrics
doge_eval['profit/loss'] = np.nan

#create column to hold buy and cell signals
doge_eval['signals'] = np.nan

#create buy and sell list containers
buy = []
sell = []

#create column that has next days price
doge_eval['next_day'] = doge_eval["Predicted"].shift(-1)

# %%
#create loop that buys if next day price is higer and sells if next day price goes down
for index, row in doge_eval.iterrows():

    if row["Predicted"] > row["next_day"]:
        doge_eval.loc[index, "signals"] = "buy"
        buy.append(row["Actual"])
        doge_eval.loc[index, "profit/loss"] = 0
    elif row["Predicted"] < row["next_day"]:
        doge_eval.loc[index, "signals"] = "sell"
        sell.append(row["Actual"])
        #doge_eval.loc[index, "profit/loss"] = sell[-1] - buy[-1]
    else:
        doge_eval.loc[index, "signals"] = "hold"

# %%
#create loop that buys if next day price is higer and sells if next day price goes down
for index, row in doge_eval.iterrows():

    if row["Predicted"] > row["next_day"]:
        doge_eval.loc[index, "signals"] = "buy"
        buy.append(row["Actual"])
        doge_eval.loc[index, "profit/loss"] = 0
    elif row["Predicted"] < row["next_day"]:
        doge_eval.loc[index, "signals"] = "sell"
        sell.append(row["Actual"])
        doge_eval.loc[index, "profit/loss"] = sell[-1] - buy[-1]
    else:
        doge_eval.loc[index, "signals"] = "hold"

# %%
doge_eval.dropna(inplace= True)

# %%
doge_eval
# Out:
#               Actual  Predicted  profit/loss signals  next_day
# Date
# 2020-12-05  0.003401   0.002790     0.000000     buy  0.002789
# 2020-12-06  0.003386   0.002789     0.000000     buy  0.002789
# 2020-12-07  0.003320   0.002789     0.000000     buy  0.002788
# 2020-12-08  0.003216   0.002788     0.000000     buy  0.002787
# 2020-12-09  0.003213   0.002787     0.000000     buy  0.002785
# ...              ...        ...          ...     ...       ...
# 2021-07-22  0.190272   0.014777     0.000000     buy  0.014627
# 2021-07-23  0.192075   0.014627     0.000000     buy  0.014550
# 2021-07-24  0.195292   0.014550     0.000000     buy  0.014537
# 2021-07-25  0.195327   0.014537     0.000035    sell  0.014573
# 2021-07-26  0.204602   0.014573     0.009310    sell  0.014664
#
# [234 rows x 5 columns]

# %%
# calculate total profit/loss and percent return for 1000 total coins

# total amount of initial capital
initial_capital = 100000

# set total amount of coins
coin_order = 100

# calculate total profit/loss
total_profit_loss = round(doge_eval["profit/loss"].sum() * coin_order, 2)

# calculate return on investemnt 
roi = round((total_profit_loss / initial_capital) * 100, 2)

# display profit/loss and roi
print(
    f"The total profit/loss of the trading model is ${total_profit_loss}, "
    f"with the total return on investment being {roi}%"
)
# Out:
# The total profit/loss of the trading model is $667.2, with the total return on investment being 0.67%

# %%
#display plot for presentation 
doge_eval2 = doge_eval.copy()

#drop next day 
doge_eval2.drop('next_day', axis=1, inplace=True)

doge_eval2.plot(title="Actual Vs. Predicted DOGE Prices")
# Out:
# <AxesSubplot:title={'center':'Actual Vs. Predicted DOGE Prices'}, xlabel='Date'>
