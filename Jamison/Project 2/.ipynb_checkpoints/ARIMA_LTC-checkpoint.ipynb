# %%
import pandas as pd
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
                        FutureWarning)
warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
                        FutureWarning)

# %%
from pathlib import Path
csvpath = Path("../Project 2/Resources/ETH_USD.csv")
df = pd.read_csv(csvpath, parse_dates=True, index_col='Date')
df.head()
# Out:
#            Currency  Closing Price (USD)  24h Open (USD)  24h High (USD)  \
# Date
# 2021-01-01      ETH           730.035168      736.709922      749.059799
# 2021-01-02      ETH           771.475757      729.732567      784.506031
# 2021-01-03      ETH           976.892681      771.794228      989.551795
# 2021-01-04      ETH          1017.862399      971.642719     1151.069389
# 2021-01-05      ETH          1123.162841     1041.496000     1126.870772
#
#             24h Low (USD)
# Date
# 2021-01-01     721.920981
# 2021-01-02     716.225886
# 2021-01-03     765.723864
# 2021-01-04     890.473806
# 2021-01-05     980.278064

# %%
df["Closing Price (USD)"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Differencing the Settle price stationarizes the time series
df["Closing Price (USD)"].diff().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # Autocorrelation and Partial Autocorrelation Analysis

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
# Plot the autocorrelation of the Settle Prices
plot_acf(df["Closing Price (USD)"], zero=False, lags=35)

# %%
# Plot the partial autocorrelation of the returns
plot_pacf(df["Closing Price (USD)"], zero=False, lags=35)

# %% [markdown]
# # ARIMA Model

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
# Create an ARIMA model
model = ARIMA(df["Closing Price (USD)"].values, order=(1, 1, 1))
# Out:
# C:\Users\Jamison\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)

# %%
# Fit the model to the data
results = model.fit()
# Out:
# C:\Users\Jamison\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)

# %%
# Print the model summary
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                    D.y   No. Observations:                  203
# Model:                 ARIMA(1, 1, 1)   Log Likelihood               -1284.339
# Method:                       css-mle   S.D. of innovations            135.328
# Date:                Sat, 24 Jul 2021   AIC                           2576.679
# Time:                        11:37:07   BIC                           2589.931
# Sample:                             1   HQIC                          2582.040
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          6.6420      9.007      0.737      0.461     -11.012      24.296
# ar.L1.D.y     -0.8324      0.110     -7.558      0.000      -1.048      -0.617
# ma.L1.D.y      0.7374      0.130      5.666      0.000       0.482       0.993
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -1.2013           +0.0000j            1.2013            0.5000
# MA.1           -1.3561           +0.0000j            1.3561            0.5000
# -----------------------------------------------------------------------------
# """

# %%
# Plot the Futures Price Forecast
pd.DataFrame(results.forecast(steps=10)[0]).plot(title="Futures Forecast")
# Out:
# <AxesSubplot:title={'center':'Futures Forecast'}>

# %% [markdown]
# # ARIMA Model using a Lag of 2

# %%
# Create an ARIMA Model and fit it to the data
model2 = ARIMA(df["Closing Price (USD)"].values, order=(2, 1, 1))
results2 = model2.fit()
# Out:
# C:\Users\Jamison\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\Jamison\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)

# %%
# print the model summary
results2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                    D.y   No. Observations:                  203
# Model:                 ARIMA(2, 1, 1)   Log Likelihood               -1284.501
# Method:                       css-mle   S.D. of innovations            135.439
# Date:                Sat, 24 Jul 2021   AIC                           2579.002
# Time:                        11:37:07   BIC                           2595.568
# Sample:                             1   HQIC                          2585.704
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          7.1259     11.010      0.647      0.517     -14.454      28.705
# ar.L1.D.y      0.3091      0.631      0.490      0.624      -0.927       1.546
# ar.L2.D.y      0.1642      0.071      2.307      0.021       0.025       0.304
# ma.L1.D.y     -0.3896      0.643     -0.606      0.545      -1.651       0.871
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.6999           +0.0000j            1.6999            0.0000
# AR.2           -3.5827           +0.0000j            3.5827            0.5000
# MA.1            2.5667           +0.0000j            2.5667            0.0000
# -----------------------------------------------------------------------------
# """

# %%
# Plot the Futures Price Forecast
pd.DataFrame(results2.forecast(steps=10)[0]).plot(title="Futures Forecast")
# Out:
# <AxesSubplot:title={'center':'Futures Forecast'}>
