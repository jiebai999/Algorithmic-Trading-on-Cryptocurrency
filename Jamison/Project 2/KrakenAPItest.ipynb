# %%
import os
import ccxt
import asyncio
import numpy as np
import pandas as pd
from dotenv import load_dotenv
import matplotlib.pyplot as plt

# %%
load_dotenv()
kraken_public_key = os.getenv("KRAKEN_PUBLIC_KEY")
kraken_secret_key = os.getenv("KRAKEN_SECRET_KEY")
kraken = ccxt.kraken({"apiKey": kraken_public_key, "secret": kraken_secret_key})

close = kraken.fetch_ticker("BTC/USD")["close"]
datetime = kraken.fetch_ticker("BTC/USD")["datetime"]
df = pd.DataFrame({"close": [close]})
df.index = pd.to_datetime([datetime])

# %%
kraken.fetch_ticker("BTC/USD")
# Out:
# {'symbol': 'BTC/USD',
#  'timestamp': 1627753218912,
#  'datetime': '2021-07-31T17:40:18.912Z',
#  'high': 42400.0,
#  'low': 38926.2,
#  'bid': 41252.7,
#  'bidVolume': None,
#  'ask': 41252.8,
#  'askVolume': None,
#  'vwap': 41186.15479,
#  'open': 42234.9,
#  'close': 41252.7,
#  'last': 41252.7,
#  'previousClose': None,
#  'change': None,
#  'percentage': None,
#  'average': None,
#  'baseVolume': 4915.95932888,
#  'quoteVolume': 202469461.86059618,
#  'info': {'a': ['41252.80000', '1', '1.000'],
#   'b': ['41252.70000', '2', '2.000'],
#   'c': ['41252.70000', '0.00130000'],
#   'v': ['2067.29192037', '4915.95932888'],
#   'p': ['41695.70577', '41186.15479'],
#   't': ['17245', '35909'],
#   'l': ['41060.90000', '38926.20000'],
#   'h': ['42400.00000', '42400.00000'],
#   'o': '42234.90000'}}

# %%
import requests

resp = requests.get('https://api.kraken.com/0/public/OHLC?pair=BTCUSD&since=0')

print(resp.json())
# Out:
# {'error': [], 'result': {'XXBTZUSD': [[1627709940, '41530.1', '41530.1', '41483.2', '41483.2', '41527.4', '0.30622326', 10], [1627710000, '41464.5', '41530.0', '41464.4', '41530.0', '41489.4', '0.21834432', 17], [1627710060, '41527.8', '41527.8', '41518.4', '41525.5', '41519.5', '0.01444682', 5], [1627710120, '41519.0', '41519.0', '41501.0', '41508.1', '41503.1', '0.33712517', 7], [1627710180, '41500.9', '41500.9', '41444.6', '41444.6', '41500.6', '0.16296667', 8], [1627710240, '41456.3', '41484.3', '41456.2', '41464.2', '41462.7', '0.30969038', 6], [1627710300, '41470.3', '41522.5', '41460.9', '41522.5', '41485.5', '0.50760304', 7], [1627710360, '41529.9', '41529.9', '41505.8', '41510.0', '41517.0', '3.70718995', 19], [1627710420, '41513.7', '41548.0', '41503.0', '41548.0', '41534.6', '7.68740750', 33], [1627710480, '41530.7', '41532.7', '41500.0', '41500.0', '41500.4', '0.50504694', 5], [1627710540, '41506.9', '41509.1', '41419.1', '41419.2', '41474.0', '2.00472912', 22], [1627710600, '41417.4', '41417.4', '41390.3', '41400.1', '41401.8', '1.46010962', 19], [1627710660, '41400.0', '41426.8', '41400.0', '41420.1', '41419.2', '0.70494768', 21], [1627710720, '41455.3', '41455.3', '41455.2', '41455.2', '41455.2', '0.